# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
mainpath="/home/juan/Documentos/DATA SCIENCE/python-ml-course-master/datasets/"
filename="customer-churn-model/Customer Churn Model.txt"
fullpath=os.path.join(mainpath, filename)
data=pd.read_csv(fullpath)

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
# %matplotlib inline

# %%
#savefig("path_donde_guardar_im.jpeg")

# %% [markdown]
# ### scatter plot

# %%
#relaciona las variables en una prueba de hipotesis
data.plot(kind="scatter", x="Day Mins", y="Day Charge")
# Out:
# <Axes: xlabel='Day Mins', ylabel='Day Charge'>

# %%
#relaciona las variables en una prueba de hipotesis
data.plot(kind="scatter", x="Night Mins", y="Night Charge")
# Out:
# <Axes: xlabel='Night Mins', ylabel='Night Charge'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
data.plot(kind="scatter", x="Day Mins", y="Day Charge", ax=axs[0][0])
data.plot(kind="scatter", x="Night Mins", y="Night Charge", ax=axs[0][1])
data.plot(kind="scatter", x="Day Calls", y="Day Charge", ax=axs[1][0])
data.plot(kind="scatter", x="Night Calls", y="Night Charge", ax=axs[1][1])
# Out:
# <Axes: xlabel='Night Calls', ylabel='Night Charge'>

# %%
data.plot(kind="scatter", x="Day Mins", y="Day Charge", ax=axs[0][0])
# Out:
# <Axes: xlabel='Day Mins', ylabel='Day Charge'>

# %% [markdown]
# ### Histogramas

# %%
#Regla de sturges dice cuantas divisiones debe tener un histograma
k=int(1+np.ceil(np.log2(3333)) )
plt.hist(data["Day Calls"], bins =k)
plt.xlabel("Número de llamadas al dia ")
plt.ylabel("Frecuencia")
plt.title("Histograma del numero de llamadas al día ")
# Out:
# Text(0.5, 1.0, 'Histograma del numero de llamadas al día ')

# %% [markdown]
# ### Botsplot, diagrama de caja y bigotes

# %%
###Botsplot , diagrama de caja de bigores, sirve para ver la distribucion de valores numericos
plt.boxplot(data['Day Calls'])
plt.ylabel("Numero de llamadas")
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')
